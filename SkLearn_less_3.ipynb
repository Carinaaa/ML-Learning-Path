# %% [markdown]
# <a href="https://colab.research.google.com/github/Carinaaa/ML-Learning-Path/blob/intro-sklearn/SkLearn_less_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 2. Choosing the right estimator/algorithm for your problem
#
# Some things to note:
# * Sklearn referes to machine learning models, algorithms as estimators
# * Classification problem - predicting a category (heart disease or not)
#   * Sometimes you'll see clf (short for classifier) used as a classification estimator
# * Regression problem - predicting a number (selling price of a car)

# %% [markdown]
# https://scikit-learn.org/stable/machine_learning_map.html
#
# https://scikit-learn.org/stable/datasets.html -> toy, real world, generated

# %%
## 2.1 Picking a mashine learning model for a regression problem
# Get CAlifornia Housing dataset
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
import pandas as pd
housing_df = pd.DataFrame(housing['data'], columns=housing['feature_names'])
housing_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
housing_df['target'] = housing['target']
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
# housing_df = housing_df.drop("MedHouseVal", axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
# import alg
from sklearn.linear_model import Ridge

# setup random seed
np.random.seed(42)

# Create the data
X = housing_df.drop("target", axis=1)
Y = housing_df["target"] # median house price in $100.000s

# Split into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# Instantiate and fit the model (on the training set)
model = Ridge()
model.fit(X_train, Y_train)

# check score
model.score(X_test, Y_test)
# Out:
# 0.5758549611440126

# %% [markdown]
# ## Coefficient of Determination
#
# The coefficient of determination is a statistical measurement that examins how differences in one variable can be explained by the difference in a second variable, when predicting the outcome of a given event.
#
# It is known as R-squared, assesses how strong the linear relationship is between two variables, and is relied on by researchers when conducting trend analysis.

# %% [markdown]
# ## checking scores for different models

# %%
from sklearn.svm import SVR

np.random.seed(42)

model_svr = SVR(kernel='linear')
model_svr.fit(X_train, Y_train)
model_svr.score(X_test, Y_test)

# %%
from sklearn.svm import SVR

np.random.seed(42)

model_srv_rbf = SVR(kernel='rbf')
model_srv_rbf.fit(X_train, Y_train)
model_srv_rbf.score(X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2992558400.py in <cell line: 0>()
# ----> 1 from sklearn.svm import SVR
#       2
#       3 np.random.seed(42)
#       4
#       5 model_srv_rbf = SVR(kernel='rbf')
#
# /usr/local/lib/python3.12/dist-packages/sklearn/__init__.py in <module>
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      75
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in <module>
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
# ...

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

np.random.seed(42)

model_hist = HistGradientBoostingRegressor(max_iter=100)
model_hist.fit(X_train, Y_train)
model_hist.score(X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3375028928.py in <cell line: 0>()
# ----> 1 from sklearn.ensemble import HistGradientBoostingRegressor
#       2
#       3 np.random.seed(42)
#       4
#       5 model_hist = HistGradientBoostingRegressor(max_iter=100)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/__init__.py in <module>
#      71     _distributor_init,
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#      75
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in <module>
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
# ...

# %%
from sklearn.linear_model import Lasso

np.random.seed(42)

model_lasso = Lasso(alpha=0.1)
model_lasso.fix(X_train, Y_train)
model_lasso.score(X_test, Y_train)

# %%
from sklearn.linear_model import ElasticNet

np.random.seed(42)

model_elastic = ElasticNet(alpha=0.1)
model_elastic.fix(X_train, Y_train)
model_elastic.score(X_test, Y_train)
